# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df = pd.read_csv('HousePrices.csv')
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  560000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline

# %%
plt.xlabel('Area(sqft)')
plt.ylabel('Price(USD)')
plt.scatter(df.area,df.price,color = 'red', marker = 'o')
plt.plot(df.area,reg.predict(df[['area']]),color = 'blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3000]])
# Out:
# c:\Users\athar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([586643.83561644])

# %%
can = linear_model.LinearRegression()

# %%
d = pd.read_csv('incomecan.csv')
d.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
d.rename(columns={'income(USD)': 'income'}, inplace=True)

# %%
d.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
plt.xlabel('Year')
plt.ylabel('Income')
plt.scatter(d.year,d.income, color = 'red', marker= 'o')
plt.plot(d.year,can.predict(d[['year']]))

# %%
can.fit(d[['year']],d.income)
# Out:
# LinearRegression()

# %%
can.predict([[2020]])
# Out:
# c:\Users\athar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
